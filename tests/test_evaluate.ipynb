# %% [markdown]
# <a href="https://colab.research.google.com/github/sunilvengalil/BloodVesselSegment/blob/master/tests/test_evaluate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.14.0
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.14.0`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/concept_learning/concept_learning
root_path="/content/gdrive/MyDrive/concept_learning/concept_learning/concept_learning_exp"
# Out:
# /content/gdrive/MyDrive/concept_learning/concept_learning

# %%
# !git pull
# Out:
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 45 (delta 26), reused 34 (delta 21), pack-reused 0
# Unpacking objects: 100% (45/45), done.
# From https://github.com/sunilvengalil/concept_learning
#    3b3c4da..a4890b8  master     -> origin/master
# Updating 3b3c4da..a4890b8
# Fast-forward
#  cifar_10_experiments/experiment_5.ipynb            | 5278 ++++++++++++++++++++
#  .../supervised_cifar_arch_vaal_test.py             |    3 +-
#  clearn/analysis/plot_metrics.py                    |   90 +-
#  clearn/experiments/experiment.py                   |   19 +-
#  clearn/models/classify/semi_supervised.py          |   82 +-
#  clearn/models/vae.py                               |    8 +-
#  clearn/utils/retention_policy/__init__.py          |    0
#  clearn/utils/retention_policy/policy.py            |   37 +
#  clearn/utils/utils.py                              |    6 +-
# ...

# %%
import tensorflow as tf

from clearn.config import ExperimentConfig
from clearn.dao.dao_factory import get_dao
from clearn.experiments.experiment import MODEL_TYPE_VAE_SEMI_SUPERVISED_CIFAR10, load_trained_model,load_model_and_test

# %%
experiment_name = "Experiment_5"
z_dim = 32
num_units = [64, 128, 64, 64]
# num_units = [128, 256, 512, 1024]
learning_rate = 1e-3
num_epochs = 100
num_runs = 1
create_split = True
run_id = 2
num_cluster_config = ExperimentConfig.NUM_CLUSTERS_CONFIG_TWO_TIMES_ELBOW
train_val_data_iterator = None
beta = 0
supervise_weight = 0
reconstruction_weight = 1
dataset_name = "cifar_10"
split_name = "split_1"
num_val_samples = 5000
dao = get_dao(dataset_name, split_name, num_val_samples)
tf.reset_default_graph()

exp_config, predicted_df = load_model_and_test(experiment_name=experiment_name,
                                                root_path=root_path,
                                                z_dim=z_dim,
                                                run_id=run_id,
                                                num_cluster_config=num_cluster_config,
                                                model_type=MODEL_TYPE_VAE_SEMI_SUPERVISED_CIFAR10,
                                                num_units=num_units,
                                                save_reconstructed_images=True,
                                                split_name=split_name,
                                                num_val_samples=num_val_samples,
                                                dataset_name=dataset_name,
                                                write_predictions=True,
                                                )
# self.assertIsNotNone(exp_config)
# self.assertIsNotNone(predicted_df)
# Out:
# Streaming output truncated to the last 5000 lines.
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# Shape of cost () Image shape (32, 32, 3)
# ...

# %%
drive.flush_and_unmount()

# %%
# !ls /content/gdrive/MyDrive/concept_learning/concept_learning/concept_learning_exp/Experiment_5/Exp_64_64_128_64_32_TWO_TIMES_ELBOW_2/prediction_results/
# Out:
# reconstructed_01_0703	reconstructed_36_0703  reconstructed_76_0703
# reconstructed_06_0703	reconstructed_41_0703  reconstructed_81_0703
# reconstructed_100_0703	reconstructed_46_0703  reconstructed_86_0703
# reconstructed_11_0703	reconstructed_51_0703  reconstructed_91_0703
# reconstructed_16_0703	reconstructed_56_0703  reconstructed_96_0001
# reconstructed_21_0703	reconstructed_61_0703  reconstructed_96_0703
# reconstructed_26_0703	reconstructed_66_0703  reconstructed_images
# reconstructed_31_0703	reconstructed_71_0703
